# %% [markdown]
# Q. 9. (a)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Define the system of first-order ODEs
def odesystem(x, y, y2_initial_guess):
    y1, y2 = y
    dy1dx = y2
    dy2dx = -np.exp(-2 * y1)
    return [dy1dx, dy2dx]

# Define the boundary conditions
x_span = (1, 2)
y1_initial = 0

# Define the target value for y(2)
y1_target = np.log(2)

# Define a function to solve the initial value problem with a given initial guess for y'(1)
def solve_ivp_with_guess(y2_initial_guess):
    sol = solve_ivp(lambda x, y: odesystem(x, y, y2_initial_guess), x_span, [y1_initial, y2_initial_guess], t_eval=[2])
    return sol.y[0][-1]

# Use a root-finding algorithm to find the correct initial guess for y'(1)
from scipy.optimize import root_scalar
y2_initial_guess = root_scalar(lambda y2: solve_ivp_with_guess(y2) - y1_target, bracket=[-1, 1]).root

# Solve the initial value problem with the correct initial guess for y'(1)
sol = solve_ivp(lambda x, y: odesystem(x, y, y2_initial_guess), x_span, [y1_initial, y2_initial_guess], t_eval=np.linspace(1, 2, 100))

# Define the exact solution function
def exact_solution(x):
    return np.log(x)

# Compute the exact solution values for the range of x values
x_values = np.linspace(1, 2, 100)
exact_y_values = exact_solution(x_values)

# Plot the numerical solution and the exact solution on the same plot
plt.plot(sol.t, sol.y[0], label='Numerical Solution', color='blue')
plt.plot(x_values, exact_y_values, label='Exact Solution', linestyle='--', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numerical vs Exact Solution')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# (b)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import root_scalar

# Define the system of first-order ODEs
def odesystem(x, y):
    y1, y2 = y
    dy1dx = y2
    dy2dx = y2 * np.cos(x) - y1 * np.log(y1)
    return [dy1dx, dy2dx]

# Define the boundary conditions
x_span = (0, np.pi/2)
y1_initial = 1

# Define the target value for y(pi/2)
y1_target = np.exp(1)

# Define a function to solve the initial value problem with a given initial guess for y'(0)
def solve_ivp_with_guess(y2_initial_guess):
    sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=[np.pi/2])
    return sol.y[0][-1]

# Use a root-finding algorithm to find the correct initial guess for y'(0)
y2_initial_guess = root_scalar(lambda y2: solve_ivp_with_guess(y2) - y1_target, bracket=[0, 2]).root

# Solve the initial value problem with the correct initial guess for y'(0)
sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=np.linspace(0, np.pi/2, 100))

# Define the exact solution function
def exact_solution(x):
    return np.exp(np.sin(x))

# Compute the exact solution values for the range of x values
x_values = np.linspace(0, np.pi/2, 100)
exact_y_values = exact_solution(x_values)

# Plot the numerical solution and the exact solution on the same plot
plt.plot(sol.t, sol.y[0], label='Numerical Solution', color='blue')
plt.plot(x_values, exact_y_values, label='Exact Solution', linestyle='--', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numerical vs Exact Solution')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# (c)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import root_scalar

# Define the system of first-order ODEs
def odesystem(x, y):
    y1, y2 = y
    dy1dx = y2
    dy2dx = -(2 * (y2 ** 3) + y1 ** 2 * y2) * 1 / np.cos(x)
    return [dy1dx, dy2dx]

# Define the boundary conditions
x_span = (np.pi/4, np.pi/3)
y1_initial = 2 ** (-1/4)

# Define the target value for y(pi/3)
y1_target = 12**(1/4) / (2)

# Define a function to solve the initial value problem with a given initial guess for y'(pi/4)
def solve_ivp_with_guess(y2_initial_guess):
    sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=[np.pi/3])
    return sol.y[0][-1]

# Use a root-finding algorithm to find the correct initial guess for y'(pi/4)
y2_initial_guess = root_scalar(lambda y2: solve_ivp_with_guess(y2) - y1_target, bracket=[0, 1]).root

# Solve the initial value problem with the correct initial guess for y'(pi/4)
sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=np.linspace(np.pi/4, np.pi/3, 100))

# Define the exact solution function
def exact_solution(x):
    return np.sin(x) ** 0.5

# Compute the exact solution values for the range of x values
x_values = np.linspace(np.pi/4, np.pi/3, 100)
exact_y_values = exact_solution(x_values)

# Plot the numerical solution and the exact solution on the same plot
plt.plot(sol.t, sol.y[0], label='Numerical Solution', color='blue')
plt.plot(x_values, exact_y_values, label='Exact Solution', linestyle='--', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numerical vs Exact Solution')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# (d)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import root_scalar

# Define the system of first-order ODEs
def odesystem(x, y):
    y1, y2 = y
    dy1dx = y2
    dy2dx = 0.5 - 0.5 * (y2 ** 2) - 0.5 * y1 * np.sin(x)
    return [dy1dx, dy2dx]

# Define the boundary conditions
x_span = (0, np.pi)
y1_initial = 2

# Define the target value for y(pi)
y1_target = 2

# Define a function to solve the initial value problem with a given initial guess for y'(0)
def solve_ivp_with_guess(y2_initial_guess):
    sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=[np.pi])
    return sol.y[0][-1]

# Use a root-finding algorithm to find the correct initial guess for y'(0)
y2_initial_guess = root_scalar(lambda y2: solve_ivp_with_guess(y2) - y1_target, bracket=[0, 1]).root

# Solve the initial value problem with the correct initial guess for y'(0)
sol = solve_ivp(lambda x, y: odesystem(x, y), x_span, [y1_initial, y2_initial_guess], t_eval=np.linspace(0, np.pi, 100))

# Define the exact solution function
def exact_solution(x):
    return 2 + np.sin(x)

# Compute the exact solution values for the range of x values
x_values = np.linspace(0, np.pi, 100)
exact_y_values = exact_solution(x_values)

# Plot the numerical solution and the exact solution on the same plot
plt.plot(sol.t, sol.y[0], label='Numerical Solution', color='blue')
plt.plot(x_values, exact_y_values, label='Exact Solution', linestyle='--', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Numerical vs Exact Solution')
plt.legend()
plt.grid(True)
plt.show()
